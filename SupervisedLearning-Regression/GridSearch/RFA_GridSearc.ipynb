# %% [markdown]
# <a href="https://colab.research.google.com/github/neogenxpert/Viku_Python/blob/neogenxpert-ML/SVM_GridSearc.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
ds=pd.read_csv("insurance_pre.csv")
ds=pd.get_dummies(ds,drop_first=True)

# %%
independent = ds.iloc[:,[0,1,2,4,5]]
dependent = ds.iloc[:,3]

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(independent,dependent,test_size=0.30,random_state=0)

# %%
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()
x_train = sc.fit_transform(x_train)
x_test = sc.transform(x_test)

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.ensemble import RandomForestRegressor
par_grid = {
        'n_estimators': [100, 200, 300],
        'max_depth': [None, 10, 20],
        'min_samples_split': [2, 5, 10]
    }
Regressor = GridSearchCV(RandomForestRegressor(),
                               par_grid,
                               cv=5, # Number of cross-validation folds
                               scoring='accuracy', # or other relevant metric like 'f1_macro', 'neg_mean_squared_error'
                               n_jobs=-1) # Use all available cores for parallel processing
Regressor.fit(x_train, y_train)
# Out:
# C:\Users\1309048\AppData\Local\anaconda3\Lib\site-packages\sklearn\model_selection\_search.py:1108: UserWarning: One or more of the test scores are non-finite: [nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan
#  nan nan nan nan nan nan nan nan nan]
#   warnings.warn(
# GridSearchCV(cv=5, estimator=RandomForestRegressor(), n_jobs=-1,
#              param_grid={'max_depth': [None, 10, 20],
#                          'min_samples_split': [2, 5, 10],
#                          'n_estimators': [100, 200, 300]},
#              scoring='accuracy')

# %%
grid = Regressor.cv_results_
print("The R_score value for the Best Paramater {} :".format(Regressor.best_params_))
# Out:
# The R_score value for the Best Paramater {'max_depth': None, 'min_samples_split': 2, 'n_estimators': 100} :

# %%
table = pd.DataFrame.from_dict(grid)
table
# Out:
#     mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 0        1.367157      0.221037         0.254661        0.106241
# 1        2.721932      0.221640         0.244235        0.106610
# 2        4.317854      0.253524         0.192845        0.053371
# 3        1.248459      0.212877         0.163485        0.146640
# 4        2.129071      0.343421         0.372049        0.227531
# 5        3.415298      0.166658         0.377993        0.086101
# 6        0.943177      0.137657         0.140223        0.120100
# 7        2.104931      0.087514         0.319966        0.105963
# 8        3.032595      0.249924         0.263668        0.074377
# 9        1.214688      0.169826         0.216672        0.126909
# 10       2.159564      0.364103         0.216212        0.135354
# 11       3.373848      0.096549         0.516403        0.396282
# 12       1.140801      0.163438         0.421786        0.182865
# 13       2.391663      0.193899         0.156330        0.091648
# 14       3.277266      0.218222         0.370407        0.109153
# 15       0.952975      0.036046         0.283871        0.165870
# 16       1.905051      0.080606         0.243029        0.097709
# 17       3.011265      0.275501         0.194143        0.080030
# 18       1.448603      0.152817         0.102399        0.086157
# 19       2.997472      0.181894         0.224322        0.085732
# 20       3.923924      0.238373         0.317678        0.128640
# 21       1.092453      0.096814         0.227882        0.152870
# 22       2.094999      0.395433         0.537748        0.232747
# 23       3.630875      0.333363         0.625224        0.277021
# 24       1.151544      0.131667         0.275769        0.197083
# 25       2.053158      0.211416         0.144902        0.062620
# 26       3.020564      0.182606         0.218412        0.110897
#
#    param_max_depth  param_min_samples_split  param_n_estimators  \
# 0             None                        2                 100
# 1             None                        2                 200
# 2             None                        2                 300
# 3             None                        5                 100
# 4             None                        5                 200
# 5             None                        5                 300
# 6             None                       10                 100
# 7             None                       10                 200
# 8             None                       10                 300
# 9               10                        2                 100
# 10              10                        2                 200
# 11              10                        2                 300
# 12              10                        5                 100
# 13              10                        5                 200
# 14              10                        5                 300
# 15              10                       10                 100
# 16              10                       10                 200
# 17              10                       10                 300
# 18              20                        2                 100
# 19              20                        2                 200
# 20              20                        2                 300
# 21              20                        5                 100
# 22              20                        5                 200
# 23              20                        5                 300
# 24              20                       10                 100
# 25              20                       10                 200
# 26              20                       10                 300
#
#                                                params  split0_test_score  \
# 0   {'max_depth': None, 'min_samples_split': 2, 'n...                NaN
# 1   {'max_depth': None, 'min_samples_split': 2, 'n...                NaN
# 2   {'max_depth': None, 'min_samples_split': 2, 'n...                NaN
# 3   {'max_depth': None, 'min_samples_split': 5, 'n...                NaN
# 4   {'max_depth': None, 'min_samples_split': 5, 'n...                NaN
# 5   {'max_depth': None, 'min_samples_split': 5, 'n...                NaN
# 6   {'max_depth': None, 'min_samples_split': 10, '...                NaN
# 7   {'max_depth': None, 'min_samples_split': 10, '...                NaN
# 8   {'max_depth': None, 'min_samples_split': 10, '...                NaN
# 9   {'max_depth': 10, 'min_samples_split': 2, 'n_e...                NaN
# 10  {'max_depth': 10, 'min_samples_split': 2, 'n_e...                NaN
# 11  {'max_depth': 10, 'min_samples_split': 2, 'n_e...                NaN
# 12  {'max_depth': 10, 'min_samples_split': 5, 'n_e...                NaN
# 13  {'max_depth': 10, 'min_samples_split': 5, 'n_e...                NaN
# 14  {'max_depth': 10, 'min_samples_split': 5, 'n_e...                NaN
# 15  {'max_depth': 10, 'min_samples_split': 10, 'n_...                NaN
# 16  {'max_depth': 10, 'min_samples_split': 10, 'n_...                NaN
# 17  {'max_depth': 10, 'min_samples_split': 10, 'n_...                NaN
# 18  {'max_depth': 20, 'min_samples_split': 2, 'n_e...                NaN
# 19  {'max_depth': 20, 'min_samples_split': 2, 'n_e...                NaN
# 20  {'max_depth': 20, 'min_samples_split': 2, 'n_e...                NaN
# 21  {'max_depth': 20, 'min_samples_split': 5, 'n_e...                NaN
# 22  {'max_depth': 20, 'min_samples_split': 5, 'n_e...                NaN
# 23  {'max_depth': 20, 'min_samples_split': 5, 'n_e...                NaN
# 24  {'max_depth': 20, 'min_samples_split': 10, 'n_...                NaN
# 25  {'max_depth': 20, 'min_samples_split': 10, 'n_...                NaN
# 26  {'max_depth': 20, 'min_samples_split': 10, 'n_...                NaN
#
#     split1_test_score  split2_test_score  split3_test_score  \
# 0                 NaN                NaN                NaN
# 1                 NaN                NaN                NaN
# 2                 NaN                NaN                NaN
# 3                 NaN                NaN                NaN
# 4                 NaN                NaN                NaN
# 5                 NaN                NaN                NaN
# 6                 NaN                NaN                NaN
# 7                 NaN                NaN                NaN
# 8                 NaN                NaN                NaN
# 9                 NaN                NaN                NaN
# 10                NaN                NaN                NaN
# 11                NaN                NaN                NaN
# 12                NaN                NaN                NaN
# 13                NaN                NaN                NaN
# 14                NaN                NaN                NaN
# 15                NaN                NaN                NaN
# 16                NaN                NaN                NaN
# 17                NaN                NaN                NaN
# 18                NaN                NaN                NaN
# 19                NaN                NaN                NaN
# 20                NaN                NaN                NaN
# 21                NaN                NaN                NaN
# 22                NaN                NaN                NaN
# 23                NaN                NaN                NaN
# 24                NaN                NaN                NaN
# 25                NaN                NaN                NaN
# 26                NaN                NaN                NaN
#
#     split4_test_score  mean_test_score  std_test_score  rank_test_score
# 0                 NaN              NaN             NaN                1
# 1                 NaN              NaN             NaN                1
# 2                 NaN              NaN             NaN                1
# 3                 NaN              NaN             NaN                1
# 4                 NaN              NaN             NaN                1
# 5                 NaN              NaN             NaN                1
# 6                 NaN              NaN             NaN                1
# 7                 NaN              NaN             NaN                1
# 8                 NaN              NaN             NaN                1
# 9                 NaN              NaN             NaN                1
# 10                NaN              NaN             NaN                1
# 11                NaN              NaN             NaN                1
# 12                NaN              NaN             NaN                1
# 13                NaN              NaN             NaN                1
# 14                NaN              NaN             NaN                1
# 15                NaN              NaN             NaN                1
# 16                NaN              NaN             NaN                1
# 17                NaN              NaN             NaN                1
# 18                NaN              NaN             NaN                1
# 19                NaN              NaN             NaN                1
# 20                NaN              NaN             NaN                1
# 21                NaN              NaN             NaN                1
# 22                NaN              NaN             NaN                1
# 23                NaN              NaN             NaN                1
# 24                NaN              NaN             NaN                1
# 25                NaN              NaN             NaN                1
# 26                NaN              NaN             NaN                1

# %%
age = float(input("Age:"))
bmi = float(input("BMI:"))
children= int(input("No of Childrens:"))
sex = int(input("Male 0 or 1:"))
smoker = int(input("Smoker Yes 0 or 1:"))

# %%
Prediction = Regressor.predict([[age,bmi,children,sex,smoker]])
print(" Prediction = {}".format(Prediction))
