# %% [markdown]
# <a href="https://colab.research.google.com/github/neogenxpert/Viku_Python/blob/neogenxpert-ML/SVM_GridSearc.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
ds=pd.read_csv("insurance_pre.csv")
ds=pd.get_dummies(ds,drop_first=True)

# %%
independent = ds.iloc[:,[0,1,2,4,5]]
dependent = ds.iloc[:,3]

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(independent,dependent,test_size=0.30,random_state=0)

# %%
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()
x_train = sc.fit_transform(x_train)
x_test = sc.transform(x_test)

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.svm import SVR
par_grid = {'kernel':['linear','rbf','sigmoid','poly'], 'C':[10,100], 'gamma':['auto','scale'] }
Regressor = GridSearchCV(SVR(), par_grid, refit = True, verbose = 3, n_jobs=-1)
Regressor.fit(x_train, y_train)
# Out:
# Fitting 5 folds for each of 16 candidates, totalling 80 fits
# GridSearchCV(estimator=SVR(), n_jobs=-1,
#              param_grid={'C': [10, 100], 'gamma': ['auto', 'scale'],
#                          'kernel': ['linear', 'rbf', 'sigmoid', 'poly']},
#              verbose=3)

# %%
grid = Regressor.cv_results_
print("The R_score value for the Best Paramater {} :".format(Regressor.best_params_))
# Out:
# The R_score value for the Best Paramater {'C': 100, 'gamma': 'auto', 'kernel': 'linear'} :

# %%
table = pd.DataFrame.from_dict(grid)
table
# Out:
#     mean_fit_time  std_fit_time  mean_score_time  std_score_time  param_C  \
# 0        0.040653      0.007896         0.011686        0.011866       10
# 1        0.042855      0.007627         0.022500        0.010805       10
# 2        0.073301      0.011326         0.011085        0.003427       10
# 3        0.024859      0.000857         0.005360        0.000404       10
# 4        0.030671      0.008601         0.008165        0.004944       10
# 5        0.041921      0.004333         0.018129        0.004035       10
# 6        0.047231      0.007098         0.009389        0.000640       10
# 7        0.025116      0.000769         0.005522        0.000498       10
# 8        0.031501      0.001283         0.005765        0.000506      100
# 9        0.031314      0.000757         0.017794        0.001352      100
# 10       0.045984      0.002870         0.008913        0.000343      100
# 11       0.027070      0.001288         0.006554        0.002792      100
# 12       0.033800      0.003441         0.006429        0.001130      100
# 13       0.033529      0.002021         0.016996        0.000993      100
# 14       0.045308      0.000870         0.010153        0.001537      100
# 15       0.028172      0.001642         0.005456        0.000444      100
#
#    param_gamma param_kernel  \
# 0         auto       linear
# 1         auto          rbf
# 2         auto      sigmoid
# 3         auto         poly
# 4        scale       linear
# 5        scale          rbf
# 6        scale      sigmoid
# 7        scale         poly
# 8         auto       linear
# 9         auto          rbf
# 10        auto      sigmoid
# 11        auto         poly
# 12       scale       linear
# 13       scale          rbf
# 14       scale      sigmoid
# 15       scale         poly
#
#                                                params  split0_test_score  \
# 0      {'C': 10, 'gamma': 'auto', 'kernel': 'linear'}           0.377969
# 1         {'C': 10, 'gamma': 'auto', 'kernel': 'rbf'}           0.004055
# 2     {'C': 10, 'gamma': 'auto', 'kernel': 'sigmoid'}           0.049905
# 3        {'C': 10, 'gamma': 'auto', 'kernel': 'poly'}           0.056274
# 4     {'C': 10, 'gamma': 'scale', 'kernel': 'linear'}           0.377969
# 5        {'C': 10, 'gamma': 'scale', 'kernel': 'rbf'}           0.004126
# 6    {'C': 10, 'gamma': 'scale', 'kernel': 'sigmoid'}           0.049644
# 7       {'C': 10, 'gamma': 'scale', 'kernel': 'poly'}           0.054964
# 8     {'C': 100, 'gamma': 'auto', 'kernel': 'linear'}           0.584474
# 9        {'C': 100, 'gamma': 'auto', 'kernel': 'rbf'}           0.300573
# 10   {'C': 100, 'gamma': 'auto', 'kernel': 'sigmoid'}           0.478364
# 11      {'C': 100, 'gamma': 'auto', 'kernel': 'poly'}           0.540643
# 12   {'C': 100, 'gamma': 'scale', 'kernel': 'linear'}           0.584474
# 13      {'C': 100, 'gamma': 'scale', 'kernel': 'rbf'}           0.301041
# 14  {'C': 100, 'gamma': 'scale', 'kernel': 'sigmoid'}           0.478930
# 15     {'C': 100, 'gamma': 'scale', 'kernel': 'poly'}           0.537117
#
#     split1_test_score  split2_test_score  split3_test_score  \
# 0            0.479601           0.317872           0.337979
# 1            0.013366          -0.103821          -0.095119
# 2            0.075905          -0.046585          -0.041004
# 3            0.069532          -0.045601          -0.025079
# 4            0.479601           0.317872           0.337979
# 5            0.013244          -0.103775          -0.095165
# 6            0.076323          -0.046798          -0.040824
# 7            0.071297          -0.046513          -0.024157
# 8            0.655818           0.553380           0.576939
# 9            0.339474           0.173708           0.217991
# 10           0.561673           0.428331           0.450454
# 11           0.575051           0.474839           0.535730
# 12           0.655818           0.553380           0.576939
# 13           0.338741           0.174086           0.217641
# 14           0.563200           0.427152           0.451250
# 15           0.579373           0.471840           0.537966
#
#     split4_test_score  mean_test_score  std_test_score  rank_test_score
# 0            0.324422         0.367569        0.059777                7
# 1           -0.101604        -0.056625        0.053504               15
# 2           -0.046507        -0.001657        0.053391               14
# 3           -0.049592         0.001107        0.051309               12
# 4            0.324422         0.367569        0.059777                7
# 5           -0.101602        -0.056634        0.053486               16
# 6           -0.046521        -0.001635        0.053474               13
# 7           -0.049652         0.001188        0.051594               11
# 8            0.546881         0.583498        0.038787                1
# 9            0.183375         0.243024        0.065733                9
# 10           0.431701         0.470105        0.049110                6
# 11           0.424640         0.510181        0.053582                3
# 12           0.546881         0.583498        0.038787                1
# 13           0.183403         0.242982        0.065542               10
# 14           0.432199         0.470546        0.049762                5
# 15           0.424478         0.510155        0.054955                4

# %%
age = float(input("Age:"))
bmi = float(input("BMI:"))
children= int(input("No of Childrens:"))
sex = int(input("Male 0 or 1:"))
smoker = int(input("Smoker Yes 0 or 1:"))
# Out:
# Age: 44
# BMI: 89.546
# No of Childrens: 3
# Male 0 or 1: 0
# Smoker Yes 0 or 1: 1

# %%
Prediction = Regressor.predict([[age,bmi,children,sex,smoker]])
print(" Prediction = {}".format(Prediction))
# Out:
#  Prediction = [193448.16215134]
