# %% [markdown]
# <a href="https://colab.research.google.com/github/neogenxpert/Viku_Python/blob/neogenxpert-ML/SVM_GridSearc.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
ds=pd.read_csv("insurance_pre.csv")
ds=pd.get_dummies(ds,drop_first=True)

# %%
independent = ds.iloc[:,[0,1,2,4,5]]
dependent = ds.iloc[:,3]

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.ensemble import RandomForestRegressor
par_grid = {
        'n_estimators': [100, 200, 300],
        'max_depth': [None, 10, 20],
        'min_samples_split': [2, 5, 10]
    }
Regressor = GridSearchCV(RandomForestRegressor(),
                               par_grid,
                               cv=5, # Number of cross-validation folds
                               scoring='accuracy', # or other relevant metric like 'f1_macro', 'neg_mean_squared_error'
                               n_jobs=-1) # Use all available cores for parallel processing
Regressor.fit(independent,dependent)
# Out:
# C:\Users\1309048\AppData\Local\anaconda3\Lib\site-packages\sklearn\model_selection\_search.py:1108: UserWarning: One or more of the test scores are non-finite: [nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan
#  nan nan nan nan nan nan nan nan nan]
#   warnings.warn(
# GridSearchCV(cv=5, estimator=RandomForestRegressor(), n_jobs=-1,
#              param_grid={'max_depth': [None, 10, 20],
#                          'min_samples_split': [2, 5, 10],
#                          'n_estimators': [100, 200, 300]},
#              scoring='accuracy')

# %%
grid = Regressor.cv_results_
print("The R_score value for the Best Paramater {} :".format(Regressor.best_params_))
# Out:
# The R_score value for the Best Paramater {'max_depth': None, 'min_samples_split': 2, 'n_estimators': 100} :

# %%
table = pd.DataFrame.from_dict(grid)
table
# Out:
#     mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 0        0.995134      0.051700         0.160527        0.033535
# 1        1.961646      0.081883         0.223480        0.037986
# 2        3.123636      0.059624         0.400407        0.152257
# 3        0.898475      0.086909         0.180965        0.056209
# 4        1.954209      0.131794         0.369199        0.149120
# 5        3.639335      0.265585         0.418405        0.161026
# 6        1.084423      0.046833         0.337799        0.076904
# 7        2.454278      0.107128         0.827837        0.445254
# 8        3.145223      0.088670         0.602924        0.480147
# 9        1.094778      0.157554         0.435259        0.314566
# 10       2.701321      0.164824         0.281919        0.080066
# 11       4.056500      0.175831         0.350537        0.264870
# 12       1.248415      0.045377         0.494289        0.284918
# 13       2.244383      0.256168         0.194441        0.092279
# 14       4.299194      0.249597         0.273642        0.131007
# 15       1.506624      0.105667         0.232224        0.092870
# 16       2.711252      0.290700         0.621117        0.360715
# 17       4.563233      0.589551         0.329035        0.161510
# 18       2.100908      0.404166         0.325154        0.156134
# 19       3.364493      0.198152         0.278051        0.076410
# 20       4.791618      0.292264         0.329073        0.136255
# 21       1.376728      0.148367         0.100170        0.088132
# 22       2.522872      0.274418         0.299448        0.116208
# 23       4.104426      0.131777         0.387578        0.103876
# 24       1.201426      0.194931         0.187179        0.053100
# 25       2.540313      0.267560         0.220248        0.129178
# 26       3.617113      0.202756         0.297476        0.149815
#
#    param_max_depth  param_min_samples_split  param_n_estimators  \
# 0             None                        2                 100
# 1             None                        2                 200
# 2             None                        2                 300
# 3             None                        5                 100
# 4             None                        5                 200
# 5             None                        5                 300
# 6             None                       10                 100
# 7             None                       10                 200
# 8             None                       10                 300
# 9               10                        2                 100
# 10              10                        2                 200
# 11              10                        2                 300
# 12              10                        5                 100
# 13              10                        5                 200
# 14              10                        5                 300
# 15              10                       10                 100
# 16              10                       10                 200
# 17              10                       10                 300
# 18              20                        2                 100
# 19              20                        2                 200
# 20              20                        2                 300
# 21              20                        5                 100
# 22              20                        5                 200
# 23              20                        5                 300
# 24              20                       10                 100
# 25              20                       10                 200
# 26              20                       10                 300
#
#                                                params  split0_test_score  \
# 0   {'max_depth': None, 'min_samples_split': 2, 'n...                NaN
# 1   {'max_depth': None, 'min_samples_split': 2, 'n...                NaN
# 2   {'max_depth': None, 'min_samples_split': 2, 'n...                NaN
# 3   {'max_depth': None, 'min_samples_split': 5, 'n...                NaN
# 4   {'max_depth': None, 'min_samples_split': 5, 'n...                NaN
# 5   {'max_depth': None, 'min_samples_split': 5, 'n...                NaN
# 6   {'max_depth': None, 'min_samples_split': 10, '...                NaN
# 7   {'max_depth': None, 'min_samples_split': 10, '...                NaN
# 8   {'max_depth': None, 'min_samples_split': 10, '...                NaN
# 9   {'max_depth': 10, 'min_samples_split': 2, 'n_e...                NaN
# 10  {'max_depth': 10, 'min_samples_split': 2, 'n_e...                NaN
# 11  {'max_depth': 10, 'min_samples_split': 2, 'n_e...                NaN
# 12  {'max_depth': 10, 'min_samples_split': 5, 'n_e...                NaN
# 13  {'max_depth': 10, 'min_samples_split': 5, 'n_e...                NaN
# 14  {'max_depth': 10, 'min_samples_split': 5, 'n_e...                NaN
# 15  {'max_depth': 10, 'min_samples_split': 10, 'n_...                NaN
# 16  {'max_depth': 10, 'min_samples_split': 10, 'n_...                NaN
# 17  {'max_depth': 10, 'min_samples_split': 10, 'n_...                NaN
# 18  {'max_depth': 20, 'min_samples_split': 2, 'n_e...                NaN
# 19  {'max_depth': 20, 'min_samples_split': 2, 'n_e...                NaN
# 20  {'max_depth': 20, 'min_samples_split': 2, 'n_e...                NaN
# 21  {'max_depth': 20, 'min_samples_split': 5, 'n_e...                NaN
# 22  {'max_depth': 20, 'min_samples_split': 5, 'n_e...                NaN
# 23  {'max_depth': 20, 'min_samples_split': 5, 'n_e...                NaN
# 24  {'max_depth': 20, 'min_samples_split': 10, 'n_...                NaN
# 25  {'max_depth': 20, 'min_samples_split': 10, 'n_...                NaN
# 26  {'max_depth': 20, 'min_samples_split': 10, 'n_...                NaN
#
#     split1_test_score  split2_test_score  split3_test_score  \
# 0                 NaN                NaN                NaN
# 1                 NaN                NaN                NaN
# 2                 NaN                NaN                NaN
# 3                 NaN                NaN                NaN
# 4                 NaN                NaN                NaN
# 5                 NaN                NaN                NaN
# 6                 NaN                NaN                NaN
# 7                 NaN                NaN                NaN
# 8                 NaN                NaN                NaN
# 9                 NaN                NaN                NaN
# 10                NaN                NaN                NaN
# 11                NaN                NaN                NaN
# 12                NaN                NaN                NaN
# 13                NaN                NaN                NaN
# 14                NaN                NaN                NaN
# 15                NaN                NaN                NaN
# 16                NaN                NaN                NaN
# 17                NaN                NaN                NaN
# 18                NaN                NaN                NaN
# 19                NaN                NaN                NaN
# 20                NaN                NaN                NaN
# 21                NaN                NaN                NaN
# 22                NaN                NaN                NaN
# 23                NaN                NaN                NaN
# 24                NaN                NaN                NaN
# 25                NaN                NaN                NaN
# 26                NaN                NaN                NaN
#
#     split4_test_score  mean_test_score  std_test_score  rank_test_score
# 0                 NaN              NaN             NaN                1
# 1                 NaN              NaN             NaN                1
# 2                 NaN              NaN             NaN                1
# 3                 NaN              NaN             NaN                1
# 4                 NaN              NaN             NaN                1
# 5                 NaN              NaN             NaN                1
# 6                 NaN              NaN             NaN                1
# 7                 NaN              NaN             NaN                1
# 8                 NaN              NaN             NaN                1
# 9                 NaN              NaN             NaN                1
# 10                NaN              NaN             NaN                1
# 11                NaN              NaN             NaN                1
# 12                NaN              NaN             NaN                1
# 13                NaN              NaN             NaN                1
# 14                NaN              NaN             NaN                1
# 15                NaN              NaN             NaN                1
# 16                NaN              NaN             NaN                1
# 17                NaN              NaN             NaN                1
# 18                NaN              NaN             NaN                1
# 19                NaN              NaN             NaN                1
# 20                NaN              NaN             NaN                1
# 21                NaN              NaN             NaN                1
# 22                NaN              NaN             NaN                1
# 23                NaN              NaN             NaN                1
# 24                NaN              NaN             NaN                1
# 25                NaN              NaN             NaN                1
# 26                NaN              NaN             NaN                1

# %%
age = float(input("Age:"))
bmi = float(input("BMI:"))
children= int(input("No of Childrens:"))
sex = int(input("Male 0 or 1:"))
smoker = int(input("Smoker Yes 0 or 1:"))

# %%
Prediction = Regressor.predict([[age,bmi,children,sex,smoker]])
print(" Prediction = {}".format(Prediction))
