# %% [markdown]
# <a href="https://colab.research.google.com/github/neogenxpert/Viku_Python/blob/neogenxpert-ML/SVM_GridSearc.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
ds=pd.read_csv("insurance_pre.csv")
ds=pd.get_dummies(ds,drop_first=True)

# %%
independent = ds.iloc[:,[0,1,2,4,5]]
dependent = ds.iloc[:,3]

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(independent,dependent,test_size=0.30,random_state=0)

# %%
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()
x_train = sc.fit_transform(x_train)
x_test = sc.transform(x_test)

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.tree import DecisionTreeRegressor
par_grid = {
        'max_depth': [None, 5, 10, 15],
        'min_samples_split': [2, 5, 10],
        'min_samples_leaf': [1, 2, 4],
        'criterion': ['squared_error', 'absolute_error']
    }
Regressor = GridSearchCV(
        DecisionTreeRegressor(),
        par_grid,
        cv=5,  # Number of cross-validation folds
        scoring='neg_mean_squared_error', # Evaluation metric (e.g., negative mean squared error for regression)
        n_jobs=-1 # Use all available CPU cores
    )
Regressor.fit(x_train, y_train)
# Out:
# GridSearchCV(cv=5, estimator=DecisionTreeRegressor(), n_jobs=-1,
#              param_grid={'criterion': ['squared_error', 'absolute_error'],
#                          'max_depth': [None, 5, 10, 15],
#                          'min_samples_leaf': [1, 2, 4],
#                          'min_samples_split': [2, 5, 10]},
#              scoring='neg_mean_squared_error')

# %%
grid = Regressor.cv_results_
print("The R_score value for the Best Paramater {} :".format(Regressor.best_params_))
# Out:
# The R_score value for the Best Paramater {'criterion': 'absolute_error', 'max_depth': 5, 'min_samples_leaf': 4, 'min_samples_split': 2} :

# %%
table = pd.DataFrame.from_dict(grid)
table
# Out:
#     mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 0        0.006122      0.000337         0.001982        0.000312
# 1        0.016617      0.014579         0.001833        0.000477
# 2        0.004143      0.000475         0.001438        0.000283
# 3        0.020912      0.020623         0.001383        0.000120
# 4        0.018684      0.020252         0.003072        0.003786
# ..            ...           ...              ...             ...
# 67       0.045783      0.020145         0.001214        0.000170
# 68       0.030639      0.011638         0.001882        0.001552
# 69       0.036033      0.027220         0.001247        0.000325
# 70       0.035340      0.019773         0.001449        0.000246
# 71       0.021916      0.003707         0.001788        0.000265
#
#    param_criterion param_max_depth  param_min_samples_leaf  \
# 0    squared_error            None                       1
# 1    squared_error            None                       1
# 2    squared_error            None                       1
# 3    squared_error            None                       2
# 4    squared_error            None                       2
# ..             ...             ...                     ...
# 67  absolute_error              15                       2
# 68  absolute_error              15                       2
# 69  absolute_error              15                       4
# 70  absolute_error              15                       4
# 71  absolute_error              15                       4
#
#     param_min_samples_split  \
# 0                         2
# 1                         5
# 2                        10
# 3                         2
# 4                         5
# ..                      ...
# 67                        5
# 68                       10
# 69                        2
# 70                        5
# 71                       10
#
#                                                params  split0_test_score  \
# 0   {'criterion': 'squared_error', 'max_depth': No...      -3.113354e+07
# 1   {'criterion': 'squared_error', 'max_depth': No...      -3.387708e+07
# 2   {'criterion': 'squared_error', 'max_depth': No...      -2.789692e+07
# 3   {'criterion': 'squared_error', 'max_depth': No...      -2.670803e+07
# 4   {'criterion': 'squared_error', 'max_depth': No...      -2.634943e+07
# ..                                                ...                ...
# 67  {'criterion': 'absolute_error', 'max_depth': 1...      -2.112362e+07
# 68  {'criterion': 'absolute_error', 'max_depth': 1...      -1.601460e+07
# 69  {'criterion': 'absolute_error', 'max_depth': 1...      -1.589553e+07
# 70  {'criterion': 'absolute_error', 'max_depth': 1...      -1.586155e+07
# 71  {'criterion': 'absolute_error', 'max_depth': 1...      -1.582594e+07
#
#     split1_test_score  split2_test_score  split3_test_score  \
# 0       -5.430162e+07      -3.466563e+07      -4.670930e+07
# 1       -4.784394e+07      -3.531839e+07      -4.111736e+07
# 2       -4.568587e+07      -3.116775e+07      -3.837379e+07
# 3       -3.745336e+07      -3.484468e+07      -3.268002e+07
# 4       -3.765911e+07      -3.406730e+07      -3.193013e+07
# ..                ...                ...                ...
# 67      -3.115954e+07      -3.427772e+07      -2.371283e+07
# 68      -2.702519e+07      -2.984388e+07      -2.250482e+07
# 69      -2.082032e+07      -2.874276e+07      -2.071948e+07
# 70      -2.081935e+07      -2.894932e+07      -2.084627e+07
# 71      -2.149682e+07      -2.869937e+07      -1.995325e+07
#
#     split4_test_score  mean_test_score  std_test_score  rank_test_score
# 0       -5.479382e+07    -4.432078e+07    9.819695e+06               67
# 1       -4.984013e+07    -4.159938e+07    6.422173e+06               64
# 2       -4.513729e+07    -3.765232e+07    7.187499e+06               59
# 3       -4.650231e+07    -3.563768e+07    6.487712e+06               57
# 4       -4.419864e+07    -3.484092e+07    5.944504e+06               53
# ..                ...              ...             ...              ...
# 67      -4.620270e+07    -3.129528e+07    8.855515e+06               38
# 68      -4.313521e+07    -2.770474e+07    9.020373e+06               27
# 69      -3.581626e+07    -2.439887e+07    7.040976e+06               10
# 70      -3.581611e+07    -2.445852e+07    7.062037e+06               13
# 71      -3.587845e+07    -2.437077e+07    7.098612e+06                8
#
# [72 rows x 17 columns]

# %%
age = float(input("Age:"))
bmi = float(input("BMI:"))
children= int(input("No of Childrens:"))
sex = int(input("Male 0 or 1:"))
smoker = int(input("Smoker Yes 0 or 1:"))
# Out:
# Age: 44
# BMI: 89.78
# No of Childrens: 3
# Male 0 or 1: 0
# Smoker Yes 0 or 1: 1

# %%
Prediction = Regressor.predict([[age,bmi,children,sex,smoker]])
print(" Prediction = {}".format(Prediction))
# Out:
#  Prediction = [47896.79135]
