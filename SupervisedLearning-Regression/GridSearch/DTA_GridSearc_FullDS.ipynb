# %% [markdown]
# <a href="https://colab.research.google.com/github/neogenxpert/Viku_Python/blob/neogenxpert-ML/SVM_GridSearc.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
ds=pd.read_csv("insurance_pre.csv")
ds=pd.get_dummies(ds,drop_first=True)

# %%
independent = ds.iloc[:,[0,1,2,4,5]]
dependent = ds.iloc[:,3]

# %%
#from sklearn.model_selection import train_test_split
#x_train,x_test,y_train,y_test=train_test_split(independent,dependent,test_size=0.30,random_state=0)

# %%
#from sklearn.preprocessing import StandardScaler
#sc = StandardScaler()
#x_train = sc.fit_transform(x_train)
#x_test = sc.transform(x_test)

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.tree import DecisionTreeRegressor
par_grid = {
        'max_depth': [None, 5, 10, 15],
        'min_samples_split': [2, 5, 10],
        'min_samples_leaf': [1, 2, 4],
        'criterion': ['squared_error', 'absolute_error']
    }
Regressor = GridSearchCV(
        DecisionTreeRegressor(),
        par_grid,
        cv=5,  # Number of cross-validation folds
        scoring='neg_mean_squared_error', # Evaluation metric (e.g., negative mean squared error for regression)
        n_jobs=-1 # Use all available CPU cores
    )
Regressor.fit(independent,dependent)
# Out:
# GridSearchCV(cv=5, estimator=DecisionTreeRegressor(), n_jobs=-1,
#              param_grid={'criterion': ['squared_error', 'absolute_error'],
#                          'max_depth': [None, 5, 10, 15],
#                          'min_samples_leaf': [1, 2, 4],
#                          'min_samples_split': [2, 5, 10]},
#              scoring='neg_mean_squared_error')

# %%
grid = Regressor.cv_results_
print("The R_score value for the Best Paramater {} :".format(Regressor.best_params_))
# Out:
# The R_score value for the Best Paramater {'criterion': 'squared_error', 'max_depth': 5, 'min_samples_leaf': 4, 'min_samples_split': 2} :

# %%
table = pd.DataFrame.from_dict(grid)
table
# Out:
#     mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 0        0.005383      0.000620         0.002019        0.000838
# 1        0.006573      0.002339         0.002384        0.001293
# 2        0.004693      0.001972         0.002524        0.002256
# 3        0.004085      0.001173         0.001465        0.000513
# 4        0.005125      0.001341         0.001715        0.000690
# ..            ...           ...              ...             ...
# 67       0.251104      0.076068         0.002741        0.000570
# 68       0.232703      0.138671         0.002414        0.000944
# 69       0.190957      0.095881         0.003351        0.000495
# 70       0.136178      0.082396         0.045133        0.084675
# 71       0.162262      0.110509         0.002927        0.000372
#
#    param_criterion param_max_depth  param_min_samples_leaf  \
# 0    squared_error            None                       1
# 1    squared_error            None                       1
# 2    squared_error            None                       1
# 3    squared_error            None                       2
# 4    squared_error            None                       2
# ..             ...             ...                     ...
# 67  absolute_error              15                       2
# 68  absolute_error              15                       2
# 69  absolute_error              15                       4
# 70  absolute_error              15                       4
# 71  absolute_error              15                       4
#
#     param_min_samples_split  \
# 0                         2
# 1                         5
# 2                        10
# 3                         2
# 4                         5
# ..                      ...
# 67                        5
# 68                       10
# 69                        2
# 70                        5
# 71                       10
#
#                                                params  split0_test_score  \
# 0   {'criterion': 'squared_error', 'max_depth': No...      -4.540015e+07
# 1   {'criterion': 'squared_error', 'max_depth': No...      -3.959852e+07
# 2   {'criterion': 'squared_error', 'max_depth': No...      -2.619309e+07
# 3   {'criterion': 'squared_error', 'max_depth': No...      -3.801946e+07
# 4   {'criterion': 'squared_error', 'max_depth': No...      -3.562776e+07
# ..                                                ...                ...
# 67  {'criterion': 'absolute_error', 'max_depth': 1...      -2.950630e+07
# 68  {'criterion': 'absolute_error', 'max_depth': 1...      -2.255277e+07
# 69  {'criterion': 'absolute_error', 'max_depth': 1...      -1.957430e+07
# 70  {'criterion': 'absolute_error', 'max_depth': 1...      -1.956512e+07
# 71  {'criterion': 'absolute_error', 'max_depth': 1...      -1.998887e+07
#
#     split1_test_score  split2_test_score  split3_test_score  \
# 0       -4.435287e+07      -4.210731e+07      -4.463007e+07
# 1       -3.912078e+07      -3.424162e+07      -3.783524e+07
# 2       -3.525846e+07      -2.954942e+07      -3.277024e+07
# 3       -4.390087e+07      -2.860789e+07      -3.325841e+07
# 4       -3.954239e+07      -2.619125e+07      -3.272806e+07
# ..                ...                ...                ...
# 67      -3.468450e+07      -2.123103e+07      -2.612781e+07
# 68      -2.925994e+07      -1.908163e+07      -2.612987e+07
# 69      -3.092217e+07      -1.913463e+07      -2.485460e+07
# 70      -3.091971e+07      -1.912206e+07      -2.484951e+07
# 71      -2.881447e+07      -1.765179e+07      -2.486273e+07
#
#     split4_test_score  mean_test_score  std_test_score  rank_test_score
# 0       -4.968003e+07    -4.523409e+07    2.478392e+06               72
# 1       -3.702900e+07    -3.756503e+07    1.895303e+06               67
# 2       -3.280313e+07    -3.131487e+07    3.137975e+06               54
# 3       -3.167317e+07    -3.509196e+07    5.352762e+06               61
# 4       -3.010707e+07    -3.283930e+07    4.569049e+06               57
# ..                ...              ...             ...              ...
# 67      -2.490032e+07    -2.728999e+07    4.546713e+06               34
# 68      -2.331099e+07    -2.406704e+07    3.433377e+06               30
# 69      -2.325560e+07    -2.354826e+07    4.276427e+06               26
# 70      -2.330477e+07    -2.355224e+07    4.278957e+06               27
# 71      -2.256012e+07    -2.277560e+07    3.870135e+06               18
#
# [72 rows x 17 columns]

# %%
age = float(input("Age:"))
bmi = float(input("BMI:"))
children= int(input("No of Childrens:"))
sex = int(input("Male 0 or 1:"))
smoker = int(input("Smoker Yes 0 or 1:"))

# %%
Prediction = Regressor.predict([[age,bmi,children,sex,smoker]])
print(" Prediction = {}".format(Prediction))
# Out:
#  Prediction = [45160.59904]
# C:\Users\1309048\AppData\Local\anaconda3\Lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but DecisionTreeRegressor was fitted with feature names
#   warnings.warn(
