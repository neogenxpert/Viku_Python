# %%
import pandas as pd

# %%
ds = pd.read_csv("CKD.csv")

# %%
#Check the balanced or imbalanced values
ds["classification"].value_counts()
# Out:
# classification
# yes    249
# no     150
# Name: count, dtype: int64

# %%
ds = pd.get_dummies(ds,drop_first=True)

# %%
#ds.columns

# %%
#Input fields
independent = ds[['age', 'bp', 'al', 'su', 'bgr', 'bu', 'sc', 'sod', 'pot', 'hrmo', 'pcv','wc', 'rc', 'sg_b', 'sg_c', 'sg_d', 'sg_e', 'rbc_normal', 'pc_normal',
       'pcc_present', 'ba_present', 'htn_yes', 'dm_yes', 'cad_yes','appet_yes', 'pe_yes', 'ane_yes']]

#output fields
dependent =ds[['classification_yes']]

# %%
#Split the data for train test
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(independent,dependent,test_size=0.30,random_state=False)

# %%
#preprocessing tool used standardize features by removing the mean and scaling to unit variance. z-score normalization.
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()
x_train = sc.fit_transform(x_train) # x - mean/std deviation
x_test = sc.transform(x_test)

# %%
from sklearn.model_selection import GridSearchCV
#Model creation 
from sklearn.ensemble import RandomForestClassifier
parm_grid = {
            'n_estimators' : [10,50,100],
            'criterion' : ['gini', 'entropy', 'log_loss'],
            'max_features' : ['sqrt', 'log2'],
            'class_weight' : ['balanced', 'balanced_subsample'],
            'random_state' : [0]
            }
Classifier = GridSearchCV(RandomForestClassifier(), parm_grid, refit = True, verbose = 3, n_jobs=-1)

Classifier.fit(x_train,y_train)
# Out:
# Fitting 5 folds for each of 36 candidates, totalling 180 fits
# C:\Users\1309048\AppData\Local\anaconda3\Lib\site-packages\sklearn\base.py:1389: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# GridSearchCV(estimator=RandomForestClassifier(), n_jobs=-1,
#              param_grid={'class_weight': ['balanced', 'balanced_subsample'],
#                          'criterion': ['gini', 'entropy', 'log_loss'],
#                          'max_features': ['sqrt', 'log2'],
#                          'n_estimators': [10, 50, 100], 'random_state': [0]},
#              verbose=3)

# %%
result = Classifier.cv_results_

# %%
y_pred = Classifier.predict(x_test)
table = pd.DataFrame.from_dict(result)
table
# Out:
#     mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 0        0.031442      0.010116         0.004589        0.000143
# 1        0.126941      0.010308         0.011099        0.003071
# 2        0.285817      0.097537         0.016427        0.005116
# 3        0.058752      0.031013         0.004798        0.000647
# 4        0.126130      0.046602         0.009449        0.001521
# 5        0.342249      0.086804         0.013910        0.002329
# 6        0.065741      0.030734         0.007202        0.005068
# 7        0.191088      0.074330         0.009636        0.002991
# 8        0.322358      0.091072         0.019668        0.012989
# 9        0.046848      0.015298         0.006394        0.002568
# 10       0.208661      0.087771         0.009279        0.003298
# 11       0.358273      0.070277         0.014789        0.005988
# 12       0.076382      0.036905         0.009625        0.006739
# 13       0.239757      0.035926         0.008911        0.002393
# 14       0.393627      0.116553         0.015705        0.004098
# 15       0.214799      0.174428         0.005904        0.001686
# 16       0.252634      0.103677         0.012627        0.007495
# 17       0.281300      0.047113         0.015211        0.002128
# 18       0.149409      0.105766         0.004323        0.000149
# 19       0.139797      0.010157         0.010169        0.004418
# 20       0.341798      0.081348         0.017349        0.003766
# 21       0.060015      0.023181         0.006865        0.004906
# 22       0.280950      0.176302         0.007772        0.000710
# 23       0.259212      0.021186         0.011893        0.000775
# 24       0.052785      0.019671         0.004373        0.000113
# 25       0.134625      0.005888         0.008843        0.001575
# 26       0.293820      0.013754         0.014633        0.003493
# 27       0.044734      0.016650         0.004198        0.000094
# 28       0.173454      0.065740         0.007846        0.000715
# 29       0.340869      0.092575         0.012581        0.000964
# 30       0.041424      0.016714         0.004746        0.000705
# 31       0.216140      0.137433         0.008012        0.000503
# 32       0.284438      0.024431         0.015454        0.004781
# 33       0.043760      0.020246         0.004708        0.000488
# 34       0.191135      0.072319         0.009927        0.002749
# 35       0.375916      0.106661         0.012344        0.001065
#
#     param_class_weight param_criterion param_max_features  param_n_estimators  \
# 0             balanced            gini               sqrt                  10
# 1             balanced            gini               sqrt                  50
# 2             balanced            gini               sqrt                 100
# 3             balanced            gini               log2                  10
# 4             balanced            gini               log2                  50
# 5             balanced            gini               log2                 100
# 6             balanced         entropy               sqrt                  10
# 7             balanced         entropy               sqrt                  50
# 8             balanced         entropy               sqrt                 100
# 9             balanced         entropy               log2                  10
# 10            balanced         entropy               log2                  50
# 11            balanced         entropy               log2                 100
# 12            balanced        log_loss               sqrt                  10
# 13            balanced        log_loss               sqrt                  50
# 14            balanced        log_loss               sqrt                 100
# 15            balanced        log_loss               log2                  10
# 16            balanced        log_loss               log2                  50
# 17            balanced        log_loss               log2                 100
# 18  balanced_subsample            gini               sqrt                  10
# 19  balanced_subsample            gini               sqrt                  50
# 20  balanced_subsample            gini               sqrt                 100
# 21  balanced_subsample            gini               log2                  10
# 22  balanced_subsample            gini               log2                  50
# 23  balanced_subsample            gini               log2                 100
# 24  balanced_subsample         entropy               sqrt                  10
# 25  balanced_subsample         entropy               sqrt                  50
# 26  balanced_subsample         entropy               sqrt                 100
# 27  balanced_subsample         entropy               log2                  10
# 28  balanced_subsample         entropy               log2                  50
# 29  balanced_subsample         entropy               log2                 100
# 30  balanced_subsample        log_loss               sqrt                  10
# 31  balanced_subsample        log_loss               sqrt                  50
# 32  balanced_subsample        log_loss               sqrt                 100
# 33  balanced_subsample        log_loss               log2                  10
# 34  balanced_subsample        log_loss               log2                  50
# 35  balanced_subsample        log_loss               log2                 100
#
#     param_random_state                                             params  \
# 0                    0  {'class_weight': 'balanced', 'criterion': 'gin...
# 1                    0  {'class_weight': 'balanced', 'criterion': 'gin...
# 2                    0  {'class_weight': 'balanced', 'criterion': 'gin...
# 3                    0  {'class_weight': 'balanced', 'criterion': 'gin...
# 4                    0  {'class_weight': 'balanced', 'criterion': 'gin...
# 5                    0  {'class_weight': 'balanced', 'criterion': 'gin...
# 6                    0  {'class_weight': 'balanced', 'criterion': 'ent...
# 7                    0  {'class_weight': 'balanced', 'criterion': 'ent...
# 8                    0  {'class_weight': 'balanced', 'criterion': 'ent...
# 9                    0  {'class_weight': 'balanced', 'criterion': 'ent...
# 10                   0  {'class_weight': 'balanced', 'criterion': 'ent...
# 11                   0  {'class_weight': 'balanced', 'criterion': 'ent...
# 12                   0  {'class_weight': 'balanced', 'criterion': 'log...
# 13                   0  {'class_weight': 'balanced', 'criterion': 'log...
# 14                   0  {'class_weight': 'balanced', 'criterion': 'log...
# 15                   0  {'class_weight': 'balanced', 'criterion': 'log...
# 16                   0  {'class_weight': 'balanced', 'criterion': 'log...
# 17                   0  {'class_weight': 'balanced', 'criterion': 'log...
# 18                   0  {'class_weight': 'balanced_subsample', 'criter...
# 19                   0  {'class_weight': 'balanced_subsample', 'criter...
# 20                   0  {'class_weight': 'balanced_subsample', 'criter...
# 21                   0  {'class_weight': 'balanced_subsample', 'criter...
# 22                   0  {'class_weight': 'balanced_subsample', 'criter...
# 23                   0  {'class_weight': 'balanced_subsample', 'criter...
# 24                   0  {'class_weight': 'balanced_subsample', 'criter...
# 25                   0  {'class_weight': 'balanced_subsample', 'criter...
# 26                   0  {'class_weight': 'balanced_subsample', 'criter...
# 27                   0  {'class_weight': 'balanced_subsample', 'criter...
# 28                   0  {'class_weight': 'balanced_subsample', 'criter...
# 29                   0  {'class_weight': 'balanced_subsample', 'criter...
# 30                   0  {'class_weight': 'balanced_subsample', 'criter...
# 31                   0  {'class_weight': 'balanced_subsample', 'criter...
# 32                   0  {'class_weight': 'balanced_subsample', 'criter...
# 33                   0  {'class_weight': 'balanced_subsample', 'criter...
# 34                   0  {'class_weight': 'balanced_subsample', 'criter...
# 35                   0  {'class_weight': 'balanced_subsample', 'criter...
#
#     split0_test_score  split1_test_score  split2_test_score  \
# 0            0.982143           0.982143           0.910714
# 1            1.000000           0.946429           0.928571
# 2            1.000000           0.964286           0.928571
# 3            1.000000           0.946429           0.982143
# 4            1.000000           0.982143           0.982143
# 5            1.000000           0.982143           0.982143
# 6            0.946429           1.000000           0.928571
# 7            0.982143           0.946429           0.928571
# 8            1.000000           0.946429           0.928571
# 9            1.000000           0.946429           0.982143
# 10           1.000000           0.946429           0.982143
# 11           1.000000           0.946429           0.982143
# 12           0.946429           1.000000           0.928571
# 13           0.982143           0.946429           0.928571
# 14           1.000000           0.946429           0.928571
# 15           1.000000           0.946429           0.982143
# 16           1.000000           0.946429           0.982143
# 17           1.000000           0.946429           0.982143
# 18           0.982143           0.928571           0.946429
# 19           1.000000           0.946429           0.964286
# 20           1.000000           0.964286           0.964286
# 21           0.982143           0.946429           1.000000
# 22           1.000000           0.982143           0.982143
# 23           1.000000           0.982143           0.964286
# 24           0.946429           0.964286           0.928571
# 25           0.964286           0.946429           0.928571
# 26           1.000000           0.964286           0.928571
# 27           0.982143           0.946429           0.982143
# 28           1.000000           0.964286           0.982143
# 29           1.000000           0.964286           0.982143
# 30           0.946429           0.964286           0.928571
# 31           0.964286           0.946429           0.928571
# 32           1.000000           0.964286           0.928571
# 33           0.982143           0.946429           0.982143
# 34           1.000000           0.964286           0.982143
# 35           1.000000           0.964286           0.982143
#
#     split3_test_score  split4_test_score  mean_test_score  std_test_score  \
# 0            0.982143           0.981818         0.967792        0.028539
# 1            0.964286           1.000000         0.967857        0.028571
# 2            0.964286           0.981818         0.967792        0.023651
# 3            0.964286           1.000000         0.978571        0.020825
# 4            0.982143           1.000000         0.989286        0.008748
# 5            0.964286           1.000000         0.985714        0.013363
# 6            0.982143           1.000000         0.971429        0.029014
# 7            0.964286           1.000000         0.964286        0.025254
# 8            0.964286           1.000000         0.967857        0.028571
# 9            0.964286           1.000000         0.978571        0.020825
# 10           0.982143           1.000000         0.982143        0.019562
# 11           0.964286           1.000000         0.978571        0.020825
# 12           0.982143           1.000000         0.971429        0.029014
# 13           0.964286           1.000000         0.964286        0.025254
# 14           0.964286           1.000000         0.967857        0.028571
# 15           0.964286           1.000000         0.978571        0.020825
# 16           0.982143           1.000000         0.982143        0.019562
# 17           0.964286           1.000000         0.978571        0.020825
# 18           0.982143           1.000000         0.967857        0.026245
# 19           0.964286           1.000000         0.975000        0.021429
# 20           0.964286           0.981818         0.974935        0.014254
# 21           0.964286           1.000000         0.978571        0.020825
# 22           0.982143           1.000000         0.989286        0.008748
# 23           0.964286           1.000000         0.982143        0.015972
# 24           0.982143           1.000000         0.964286        0.025254
# 25           0.964286           1.000000         0.960714        0.023690
# 26           0.964286           1.000000         0.971429        0.026726
# 27           0.964286           1.000000         0.975000        0.018211
# 28           0.964286           1.000000         0.982143        0.015972
# 29           0.964286           1.000000         0.982143        0.015972
# 30           0.982143           1.000000         0.964286        0.025254
# 31           0.964286           1.000000         0.960714        0.023690
# 32           0.964286           1.000000         0.971429        0.026726
# 33           0.964286           1.000000         0.975000        0.018211
# 34           0.964286           1.000000         0.982143        0.015972
# 35           0.964286           1.000000         0.982143        0.015972
#
#     rank_test_score
# 0                29
# 1                25
# 2                29
# 3                11
# 4                 1
# 5                 3
# 6                21
# 7                31
# 8                25
# 9                11
# 10                9
# 11               11
# 12               21
# 13               31
# 14               25
# 15               11
# 16                9
# 17               11
# 18               28
# 19               17
# 20               20
# 21               11
# 22                1
# 23                4
# 24               31
# 25               35
# 26               21
# 27               17
# 28                4
# 29                4
# 30               31
# 31               35
# 32               21
# 33               17
# 34                4
# 35                4

# %%
# Get the metrics
from sklearn.metrics import confusion_matrix
matric = confusion_matrix(y_test,y_pred)
print(matric)
# Out:
# [[45  0]
#  [ 0 75]]

# %%
# get the classification report
from sklearn.metrics import classification_report
report = classification_report(y_test,y_pred)
print(report)
# Out:
#               precision    recall  f1-score   support
#
#        False       1.00      1.00      1.00        45
#         True       1.00      1.00      1.00        75
#
#     accuracy                           1.00       120
#    macro avg       1.00      1.00      1.00       120
# weighted avg       1.00      1.00      1.00       120

# %%
# Key to built the model
# How well model supports for overall call model
from sklearn.metrics import f1_score
f1_macro = f1_score (y_test,y_pred,average='weighted')
print ("The best value for Parameter {}:".format(Classifier.best_params_),f1_macro)
# Out:
# The best value for Parameter {'class_weight': 'balanced', 'criterion': 'gini', 'max_features': 'log2', 'n_estimators': 50, 'random_state': 0}: 1.0

# %%
# receiver operating characteristic and Area under the curve
# How well model supports for Class 0 and class 1
from sklearn.metrics import roc_auc_score
roc_auc = roc_auc_score (y_test,Classifier.predict_proba(x_test)[:,1]) # : tell all rows, take 1 ist colum of all rows for probability 
print ("The best value for Parameter {}:".format(Classifier.best_params_),roc_auc)
# Out:
# The best value for Parameter {'class_weight': 'balanced', 'criterion': 'gini', 'max_features': 'log2', 'n_estimators': 50, 'random_state': 0}: 1.0
