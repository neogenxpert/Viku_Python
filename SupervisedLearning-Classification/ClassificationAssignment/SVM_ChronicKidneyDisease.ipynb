# %%
import pandas as pd

# %%
ds = pd.read_csv("CKD.csv")

# %%
#Check the balanced or imbalanced values
ds["classification"].value_counts()
# Out:
# classification
# yes    249
# no     150
# Name: count, dtype: int64

# %%
ds = pd.get_dummies(ds,drop_first=True)

# %%
ds.columns
# Out:
# Index(['age', 'bp', 'al', 'su', 'bgr', 'bu', 'sc', 'sod', 'pot', 'hrmo', 'pcv',
#        'wc', 'rc', 'sg_b', 'sg_c', 'sg_d', 'sg_e', 'rbc_normal', 'pc_normal',
#        'pcc_present', 'ba_present', 'htn_yes', 'dm_yes', 'cad_yes',
#        'appet_yes', 'pe_yes', 'ane_yes', 'classification_yes'],
#       dtype='object')

# %%
#Input fields
independent = ds[['age', 'bp', 'al', 'su', 'bgr', 'bu', 'sc', 'sod', 'pot', 'hrmo', 'pcv','wc', 'rc', 'sg_b', 'sg_c', 'sg_d', 'sg_e', 'rbc_normal', 'pc_normal',
       'pcc_present', 'ba_present', 'htn_yes', 'dm_yes', 'cad_yes','appet_yes', 'pe_yes', 'ane_yes']]

# %%
#output fields
dependent =ds[['classification_yes']]

# %%
#Split the data for train test
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(independent,dependent,test_size=0.30,random_state=False)

# %%
#preprocessing tool used standardize features by removing the mean and scaling to unit variance. z-score normalization.
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()
x_train = sc.fit_transform(x_train) # x - mean/std deviation
x_test = sc.transform(x_test)

# %%
from sklearn.model_selection import GridSearchCV
#Model creation 
from sklearn.svm import SVC
parm_grid = {
            'kernel' : ['linear', 'poly', 'rbf', 'sigmoid'],
             'gamma' : ['scale', 'auto'],
             'C': [0.1, 1, 10, 100]
            }
Classifier = GridSearchCV(SVC(probability=True), parm_grid, refit = True, verbose = 3, n_jobs=-1)

Classifier.fit(x_train,y_train)
# Out:
# Fitting 5 folds for each of 32 candidates, totalling 160 fits
# C:\Users\hitov\anaconda3\Lib\site-packages\sklearn\utils\validation.py:1339: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# GridSearchCV(estimator=SVC(probability=True), n_jobs=-1,
#              param_grid={'C': [0.1, 1, 10, 100], 'gamma': ['scale', 'auto'],
#                          'kernel': ['linear', 'poly', 'rbf', 'sigmoid']},
#              verbose=3)

# %%
result = Classifier.cv_results_

# %%
y_pred = Classifier.predict(x_test)
table = pd.DataFrame.from_dict(result)
table
# Out:
#     mean_fit_time  std_fit_time  mean_score_time  std_score_time  param_C  \
# 0        0.063980      0.016561         0.013966        0.001179      0.1
# 1        0.084793      0.032523         0.015155        0.001819      0.1
# 2        0.102880      0.039391         0.019898        0.003854      0.1
# 3        0.066716      0.008951         0.014721        0.002388      0.1
# 4        0.084398      0.074070         0.012231        0.003394      0.1
# 5        0.099131      0.043580         0.011599        0.000888      0.1
# 6        0.071346      0.033459         0.012052        0.004027      0.1
# 7        0.068991      0.039547         0.012066        0.003370      0.1
# 8        0.050248      0.043589         0.011649        0.003181      1.0
# 9        0.108281      0.084338         0.010675        0.001613      1.0
# 10       0.047823      0.025066         0.011218        0.003759      1.0
# 11       0.064754      0.037947         0.009759        0.001758      1.0
# 12       0.075859      0.038161         0.005728        0.002667      1.0
# 13       0.086656      0.034577         0.010831        0.004158      1.0
# 14       0.055850      0.038605         0.009405        0.001227      1.0
# 15       0.097201      0.038516         0.012693        0.002096      1.0
# 16       0.061877      0.024860         0.009198        0.004368     10.0
# 17       0.059425      0.029224         0.011318        0.003208     10.0
# 18       0.057635      0.020591         0.007908        0.003513     10.0
# 19       0.082822      0.044819         0.008028        0.003748     10.0
# 20       0.056687      0.041856         0.009288        0.001889     10.0
# 21       0.062689      0.027247         0.010203        0.002567     10.0
# 22       0.094262      0.019948         0.012012        0.001868     10.0
# 23       0.062244      0.017423         0.005345        0.003614     10.0
# 24       0.081207      0.041182         0.012778        0.004752    100.0
# 25       0.063324      0.030816         0.011054        0.003519    100.0
# 26       0.069982      0.002788         0.011308        0.001535    100.0
# 27       0.088936      0.022867         0.011028        0.000999    100.0
# 28       0.073352      0.037434         0.009456        0.001606    100.0
# 29       0.081927      0.032151         0.007717        0.003534    100.0
# 30       0.051070      0.038911         0.008327        0.002282    100.0
# 31       0.047118      0.022606         0.009046        0.003175    100.0
#
#    param_gamma param_kernel  \
# 0        scale       linear
# 1        scale         poly
# 2        scale          rbf
# 3        scale      sigmoid
# 4         auto       linear
# 5         auto         poly
# 6         auto          rbf
# 7         auto      sigmoid
# 8        scale       linear
# 9        scale         poly
# 10       scale          rbf
# 11       scale      sigmoid
# 12        auto       linear
# 13        auto         poly
# 14        auto          rbf
# 15        auto      sigmoid
# 16       scale       linear
# 17       scale         poly
# 18       scale          rbf
# 19       scale      sigmoid
# 20        auto       linear
# 21        auto         poly
# 22        auto          rbf
# 23        auto      sigmoid
# 24       scale       linear
# 25       scale         poly
# 26       scale          rbf
# 27       scale      sigmoid
# 28        auto       linear
# 29        auto         poly
# 30        auto          rbf
# 31        auto      sigmoid
#
#                                                params  split0_test_score  \
# 0    {'C': 0.1, 'gamma': 'scale', 'kernel': 'linear'}           1.000000
# 1      {'C': 0.1, 'gamma': 'scale', 'kernel': 'poly'}           0.625000
# 2       {'C': 0.1, 'gamma': 'scale', 'kernel': 'rbf'}           0.964286
# 3   {'C': 0.1, 'gamma': 'scale', 'kernel': 'sigmoid'}           0.982143
# 4     {'C': 0.1, 'gamma': 'auto', 'kernel': 'linear'}           1.000000
# 5       {'C': 0.1, 'gamma': 'auto', 'kernel': 'poly'}           0.625000
# 6        {'C': 0.1, 'gamma': 'auto', 'kernel': 'rbf'}           0.964286
# 7    {'C': 0.1, 'gamma': 'auto', 'kernel': 'sigmoid'}           0.982143
# 8      {'C': 1, 'gamma': 'scale', 'kernel': 'linear'}           0.982143
# 9        {'C': 1, 'gamma': 'scale', 'kernel': 'poly'}           0.982143
# 10        {'C': 1, 'gamma': 'scale', 'kernel': 'rbf'}           0.982143
# 11    {'C': 1, 'gamma': 'scale', 'kernel': 'sigmoid'}           1.000000
# 12      {'C': 1, 'gamma': 'auto', 'kernel': 'linear'}           0.982143
# 13        {'C': 1, 'gamma': 'auto', 'kernel': 'poly'}           0.982143
# 14         {'C': 1, 'gamma': 'auto', 'kernel': 'rbf'}           0.982143
# 15     {'C': 1, 'gamma': 'auto', 'kernel': 'sigmoid'}           1.000000
# 16    {'C': 10, 'gamma': 'scale', 'kernel': 'linear'}           0.982143
# 17      {'C': 10, 'gamma': 'scale', 'kernel': 'poly'}           1.000000
# 18       {'C': 10, 'gamma': 'scale', 'kernel': 'rbf'}           0.982143
# 19   {'C': 10, 'gamma': 'scale', 'kernel': 'sigmoid'}           0.982143
# 20     {'C': 10, 'gamma': 'auto', 'kernel': 'linear'}           0.982143
# 21       {'C': 10, 'gamma': 'auto', 'kernel': 'poly'}           1.000000
# 22        {'C': 10, 'gamma': 'auto', 'kernel': 'rbf'}           0.982143
# 23    {'C': 10, 'gamma': 'auto', 'kernel': 'sigmoid'}           0.982143
# 24   {'C': 100, 'gamma': 'scale', 'kernel': 'linear'}           0.982143
# 25     {'C': 100, 'gamma': 'scale', 'kernel': 'poly'}           0.964286
# 26      {'C': 100, 'gamma': 'scale', 'kernel': 'rbf'}           0.982143
# 27  {'C': 100, 'gamma': 'scale', 'kernel': 'sigmoid'}           0.982143
# 28    {'C': 100, 'gamma': 'auto', 'kernel': 'linear'}           0.982143
# 29      {'C': 100, 'gamma': 'auto', 'kernel': 'poly'}           0.964286
# 30       {'C': 100, 'gamma': 'auto', 'kernel': 'rbf'}           0.982143
# 31   {'C': 100, 'gamma': 'auto', 'kernel': 'sigmoid'}           0.982143
#
#     split1_test_score  split2_test_score  split3_test_score  \
# 0            1.000000           0.946429           1.000000
# 1            0.642857           0.625000           0.625000
# 2            0.982143           0.946429           1.000000
# 3            0.964286           0.964286           0.982143
# 4            1.000000           0.946429           1.000000
# 5            0.625000           0.625000           0.625000
# 6            0.982143           0.946429           1.000000
# 7            0.964286           0.964286           0.982143
# 8            1.000000           0.982143           0.982143
# 9            0.982143           0.964286           0.964286
# 10           1.000000           0.964286           1.000000
# 11           1.000000           0.946429           1.000000
# 12           1.000000           0.982143           0.982143
# 13           0.982143           0.964286           0.964286
# 14           1.000000           0.964286           1.000000
# 15           1.000000           0.946429           1.000000
# 16           0.982143           0.982143           0.982143
# 17           1.000000           0.964286           1.000000
# 18           1.000000           0.982143           1.000000
# 19           1.000000           0.982143           1.000000
# 20           0.982143           0.982143           0.982143
# 21           1.000000           0.964286           1.000000
# 22           1.000000           0.982143           1.000000
# 23           1.000000           0.982143           1.000000
# 24           0.982143           0.982143           0.982143
# 25           1.000000           0.982143           1.000000
# 26           1.000000           0.982143           0.982143
# 27           0.982143           0.982143           0.982143
# 28           0.982143           0.982143           0.982143
# 29           1.000000           0.982143           1.000000
# 30           1.000000           0.982143           0.982143
# 31           0.982143           0.982143           0.982143
#
#     split4_test_score  mean_test_score  std_test_score  rank_test_score
# 0            1.000000         0.989286        0.021429                5
# 1            0.618182         0.627208        0.008258               31
# 2            0.981818         0.974935        0.018186               25
# 3            0.981818         0.974935        0.008696               25
# 4            1.000000         0.989286        0.021429                5
# 5            0.618182         0.623636        0.002727               32
# 6            0.981818         0.974935        0.018186               25
# 7            0.981818         0.974935        0.008696               25
# 8            1.000000         0.989286        0.008748                5
# 9            0.981818         0.974935        0.008696               25
# 10           0.981818         0.985649        0.013381               15
# 11           0.981818         0.985649        0.020836               19
# 12           1.000000         0.989286        0.008748                5
# 13           0.981818         0.974935        0.008696               25
# 14           0.981818         0.985649        0.013381               15
# 15           0.981818         0.985649        0.020836               19
# 16           0.981818         0.982078        0.000130               21
# 17           0.981818         0.989221        0.014319               11
# 18           1.000000         0.992857        0.008748                1
# 19           1.000000         0.992857        0.008748                1
# 20           0.981818         0.982078        0.000130               21
# 21           0.981818         0.989221        0.014319               11
# 22           1.000000         0.992857        0.008748                1
# 23           1.000000         0.992857        0.008748                1
# 24           0.981818         0.982078        0.000130               21
# 25           0.981818         0.985649        0.013381               15
# 26           1.000000         0.989286        0.008748                5
# 27           1.000000         0.985714        0.007143               13
# 28           0.981818         0.982078        0.000130               21
# 29           0.981818         0.985649        0.013381               15
# 30           1.000000         0.989286        0.008748                5
# 31           1.000000         0.985714        0.007143               13

# %%
# Get the metrics
from sklearn.metrics import confusion_matrix
matric = confusion_matrix(y_test,y_pred)
print(matric)
# Out:
# [[45  0]
#  [ 2 73]]

# %%
# get the classification report
from sklearn.metrics import classification_report
report = classification_report(y_test,y_pred)
print(report)
# Out:
#               precision    recall  f1-score   support
#
#        False       0.96      1.00      0.98        45
#         True       1.00      0.97      0.99        75
#
#     accuracy                           0.98       120
#    macro avg       0.98      0.99      0.98       120
# weighted avg       0.98      0.98      0.98       120

# %%
# Key to built the model
# How well model supports for overall call model
from sklearn.metrics import f1_score
f1_macro = f1_score (y_test,y_pred,average='weighted')
print ("The best value for Parameter {}:".format(Classifier.best_params_),f1_macro)
# Out:
# The best value for Parameter {'C': 10, 'gamma': 'scale', 'kernel': 'rbf'}: 0.9834018801410106

# %%
# receiver operating characteristic and Area under the curve
# How well model supports for Class 0 and class 1
from sklearn.metrics import roc_auc_score
roc_auc = roc_auc_score (y_test,Classifier.predict_proba(x_test)[:,1]) # : tell all rows, take 1 ist colum of all rows for probability 
print ("The best value for Parameter {}:".format(Classifier.best_params_),roc_auc)
# Out:
# The best value for Parameter {'C': 10, 'gamma': 'scale', 'kernel': 'rbf'}: 0.9994074074074074
